# %%
# ---------------------------------
# PINN: Von Karman Vortex (Re=100)
# ---------------------------------
import scipy.io
import numpy as np
import tensorflow as tf
import os
import sys
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()

sys.path.append(os.path.abspath(os.path.join(current_dir, '..')))
from model import PhysicsInformedNN
# Out:
# 2026-06-28 20:11:09.418451: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-28 20:11:09.435406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782695469.454649   16262 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782695469.460208   16262 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-28 20:11:09.479300: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
if __name__ == "__main__": 
    
    # Hyperparameters configuration
    N_train = 5000
    layers = [3, 50, 50, 50, 50, 50, 50, 50, 50, 2]
    noise_level = 0.05
    
    # Load simulation data
    data = scipy.io.loadmat('../Data/cylinder_nektar_wake.mat')
    U_star = data['U_star'] 
    P_star = data['p_star'] 
    t_star = data['t']      
    X_star = data['X_star'] 

    x_star = X_star[:,0:1]; y_star = X_star[:,1:2]
    N = X_star.shape[0]; T = t_star.shape[0]

    # Grid tile and data flattening
    XX = np.tile(X_star[:,0:1], (1,T)); YY = np.tile(X_star[:,1:2], (1,T)); TT = np.tile(t_star, (1,N)).T 
    UU = U_star[:,0,:]; VV = U_star[:,1,:]; PP = P_star 
    
    x = XX.flatten()[:,None]; y = YY.flatten()[:,None]; t = TT.flatten()[:,None] 
    u = UU.flatten()[:,None]; v = VV.flatten()[:,None]; p = PP.flatten()[:,None] 

    # Domain bounds
    lb = np.array([x.min(), y.min(), t.min()])
    ub = np.array([x.max(), y.max(), t.max()])
    lb_tf = tf.constant(lb, dtype=tf.float32)
    ub_tf = tf.constant(ub, dtype=tf.float32)

    # Random selection of training points
    idx = np.random.choice(N*T, N_train, replace=False)
    x_train = x[idx,:]; y_train = y[idx,:]; t_train = t[idx,:]
    u_train = u[idx,:]; v_train = v[idx,:]

    # Gaussian Noise
    u_train = u_train + noise_level * np.std(u_train) * np.random.randn(*u_train.shape)
    v_train = v_train + noise_level * np.std(v_train) * np.random.randn(*v_train.shape)

    # Convert to TensorFlow tensors
    x_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
    y_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)
    t_tf = tf.convert_to_tensor(t_train, dtype=tf.float32)
    u_tf = tf.convert_to_tensor(u_train, dtype=tf.float32)
    v_tf = tf.convert_to_tensor(v_train, dtype=tf.float32)

    # Training
    model = PhysicsInformedNN(layers, lb_tf, ub_tf)
    
    print("   >>> Phase 1: Data Fitting ...")
    model.train(x_tf, y_tf, t_tf, u_tf, v_tf, epochs=3000, train_params=False, physics_weight=0.0)

    model.reset_optimizer()

    print("   >>> Phase 2: Physics Discovery ...")
    model.train(x_tf, y_tf, t_tf, u_tf, v_tf, epochs=25000, train_params=True, physics_weight=1.0)
    
    # Prediction
    snap = 90 
    if snap >= T: snap = T-1

    x_star_test = X_star[:,0:1]
    y_star_test = X_star[:,1:2]
    t_star_test = TT[:, snap] 
    
    x_test_tf = tf.reshape(tf.convert_to_tensor(x_star_test, dtype=tf.float32), [-1, 1])
    y_test_tf = tf.reshape(tf.convert_to_tensor(y_star_test, dtype=tf.float32), [-1, 1])
    t_test_tf = tf.reshape(tf.convert_to_tensor(t_star_test, dtype=tf.float32), [-1, 1])

    u_pred_tf, v_pred_tf, p_pred_tf, _, _ = model.net_NS(x_test_tf, y_test_tf, t_test_tf)
    
    # Retrieve loss history
    loss_total = np.array(model.loss_history['total'])
    loss_data = np.array(model.loss_history['data'])
    loss_phys = np.array(model.loss_history['phys'])

    # Save results to compressed .npz file
    np.savez('Results/Karman/cylinder_results.npz',
             u_pred=u_pred_tf.numpy(), 
             v_pred=v_pred_tf.numpy(), 
             p_pred=p_pred_tf.numpy(), 
             lambda_1=model.lambda_1.numpy()[0], 
             lambda_2=model.lambda_2.numpy()[0],
             x_train=x_train, y_train=y_train, snap=snap,
             loss_total=loss_total, 
             loss_data=loss_data, 
             loss_phys=loss_phys)
             
    print('Done!')
# Out:
#    >>> Fase 1: Ajuste de Datos (Physics OFF)...
# /home/forero/Dev/venv/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:735: UserWarning: Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# It: 0 [PARAMS:OFF|PHYS:OFF], Loss: 7.936e-01, l1: 1.0000, l2: 0.01000, Time: 9.69s
# It: 100 [PARAMS:OFF|PHYS:OFF], Loss: 1.584e-01, l1: 1.0000, l2: 0.01000, Time: 71.86s
# It: 200 [PARAMS:OFF|PHYS:OFF], Loss: 9.998e-02, l1: 1.0000, l2: 0.01000, Time: 72.76s
# It: 300 [PARAMS:OFF|PHYS:OFF], Loss: 9.399e-02, l1: 1.0000, l2: 0.01000, Time: 69.51s
# It: 400 [PARAMS:OFF|PHYS:OFF], Loss: 9.339e-02, l1: 1.0000, l2: 0.01000, Time: 69.06s
# It: 500 [PARAMS:OFF|PHYS:OFF], Loss: 9.303e-02, l1: 1.0000, l2: 0.01000, Time: 69.29s
# It: 600 [PARAMS:OFF|PHYS:OFF], Loss: 9.343e-02, l1: 1.0000, l2: 0.01000, Time: 69.18s
# It: 700 [PARAMS:OFF|PHYS:OFF], Loss: 9.273e-02, l1: 1.0000, l2: 0.01000, Time: 69.33s
# It: 800 [PARAMS:OFF|PHYS:OFF], Loss: 9.259e-02, l1: 1.0000, l2: 0.01000, Time: 69.03s
# It: 900 [PARAMS:OFF|PHYS:OFF], Loss: 9.302e-02, l1: 1.0000, l2: 0.01000, Time: 69.08s
# It: 1000 [PARAMS:OFF|PHYS:OFF], Loss: 9.231e-02, l1: 1.0000, l2: 0.01000, Time: 68.72s
# It: 1100 [PARAMS:OFF|PHYS:OFF], Loss: 9.209e-02, l1: 1.0000, l2: 0.01000, Time: 69.17s
# It: 1200 [PARAMS:OFF|PHYS:OFF], Loss: 9.159e-02, l1: 1.0000, l2: 0.01000, Time: 69.29s
# It: 1300 [PARAMS:OFF|PHYS:OFF], Loss: 9.110e-02, l1: 1.0000, l2: 0.01000, Time: 69.03s
# It: 1400 [PARAMS:OFF|PHYS:OFF], Loss: 9.047e-02, l1: 1.0000, l2: 0.01000, Time: 68.91s
# It: 1500 [PARAMS:OFF|PHYS:OFF], Loss: 9.031e-02, l1: 1.0000, l2: 0.01000, Time: 68.97s
# It: 1600 [PARAMS:OFF|PHYS:OFF], Loss: 8.972e-02, l1: 1.0000, l2: 0.01000, Time: 69.05s
# It: 1700 [PARAMS:OFF|PHYS:OFF], Loss: 8.951e-02, l1: 1.0000, l2: 0.01000, Time: 68.99s
# It: 1800 [PARAMS:OFF|PHYS:OFF], Loss: 8.910e-02, l1: 1.0000, l2: 0.01000, Time: 68.97s
# It: 1900 [PARAMS:OFF|PHYS:OFF], Loss: 9.028e-02, l1: 1.0000, l2: 0.01000, Time: 68.93s
# It: 2000 [PARAMS:OFF|PHYS:OFF], Loss: 8.858e-02, l1: 1.0000, l2: 0.01000, Time: 69.00s
# It: 2100 [PARAMS:OFF|PHYS:OFF], Loss: 8.931e-02, l1: 1.0000, l2: 0.01000, Time: 69.29s
# It: 2200 [PARAMS:OFF|PHYS:OFF], Loss: 8.815e-02, l1: 1.0000, l2: 0.01000, Time: 68.90s
# It: 2300 [PARAMS:OFF|PHYS:OFF], Loss: 8.785e-02, l1: 1.0000, l2: 0.01000, Time: 68.47s
# It: 2400 [PARAMS:OFF|PHYS:OFF], Loss: 8.772e-02, l1: 1.0000, l2: 0.01000, Time: 69.25s
# It: 2500 [PARAMS:OFF|PHYS:OFF], Loss: 8.727e-02, l1: 1.0000, l2: 0.01000, Time: 69.38s
# It: 2600 [PARAMS:OFF|PHYS:OFF], Loss: 8.833e-02, l1: 1.0000, l2: 0.01000, Time: 69.55s
# It: 2700 [PARAMS:OFF|PHYS:OFF], Loss: 8.623e-02, l1: 1.0000, l2: 0.01000, Time: 69.16s
# It: 2800 [PARAMS:OFF|PHYS:OFF], Loss: 8.675e-02, l1: 1.0000, l2: 0.01000, Time: 69.15s
# It: 2900 [PARAMS:OFF|PHYS:OFF], Loss: 9.702e-02, l1: 1.0000, l2: 0.01000, Time: 68.76s
#  Optimizador reiniciado correctamente.
#    >>> Fase 2: Descubriendo Física (Navier-Stokes ON)...
# It: 0 [PARAMS:ON|PHYS:ON], Loss: 1.387e-01, l1: 1.0000, l2: 0.00900, Time: 8.41s
# It: 100 [PARAMS:ON|PHYS:ON], Loss: 8.810e-02, l1: 1.0000, l2: 0.02751, Time: 69.67s
# It: 200 [PARAMS:ON|PHYS:ON], Loss: 8.738e-02, l1: 1.0000, l2: 0.02875, Time: 69.00s
# It: 300 [PARAMS:ON|PHYS:ON], Loss: 8.673e-02, l1: 1.0000, l2: 0.03006, Time: 69.58s
# It: 400 [PARAMS:ON|PHYS:ON], Loss: 8.609e-02, l1: 1.0000, l2: 0.03115, Time: 69.53s
# It: 500 [PARAMS:ON|PHYS:ON], Loss: 8.629e-02, l1: 1.0000, l2: 0.03376, Time: 69.60s
# It: 600 [PARAMS:ON|PHYS:ON], Loss: 8.247e-02, l1: 1.0000, l2: 0.03277, Time: 69.13s
# It: 700 [PARAMS:ON|PHYS:ON], Loss: 2.935e-02, l1: 1.0000, l2: 0.01921, Time: 69.47s
# It: 800 [PARAMS:ON|PHYS:ON], Loss: 1.943e-02, l1: 1.0000, l2: 0.01748, Time: 69.22s
# It: 900 [PARAMS:ON|PHYS:ON], Loss: 1.615e-02, l1: 1.0000, l2: 0.01685, Time: 69.58s
# It: 1000 [PARAMS:ON|PHYS:ON], Loss: 1.203e-02, l1: 1.0000, l2: 0.01620, Time: 69.43s
# It: 1100 [PARAMS:ON|PHYS:ON], Loss: 9.994e-03, l1: 1.0000, l2: 0.01526, Time: 69.28s
# It: 1200 [PARAMS:ON|PHYS:ON], Loss: 8.666e-03, l1: 1.0000, l2: 0.01460, Time: 69.29s
# It: 1300 [PARAMS:ON|PHYS:ON], Loss: 7.519e-03, l1: 1.0000, l2: 0.01426, Time: 69.23s
# It: 1400 [PARAMS:ON|PHYS:ON], Loss: 6.881e-03, l1: 1.0000, l2: 0.01417, Time: 69.59s
# It: 1500 [PARAMS:ON|PHYS:ON], Loss: 6.061e-03, l1: 1.0000, l2: 0.01403, Time: 69.54s
# It: 1600 [PARAMS:ON|PHYS:ON], Loss: 5.471e-03, l1: 1.0000, l2: 0.01392, Time: 68.83s
# It: 1700 [PARAMS:ON|PHYS:ON], Loss: 5.203e-03, l1: 1.0000, l2: 0.01387, Time: 69.51s
# It: 1800 [PARAMS:ON|PHYS:ON], Loss: 4.846e-03, l1: 1.0000, l2: 0.01360, Time: 69.71s
# It: 1900 [PARAMS:ON|PHYS:ON], Loss: 4.421e-03, l1: 1.0000, l2: 0.01338, Time: 69.43s
# It: 2000 [PARAMS:ON|PHYS:ON], Loss: 4.384e-03, l1: 1.0000, l2: 0.01325, Time: 69.21s
# It: 2100 [PARAMS:ON|PHYS:ON], Loss: 4.512e-03, l1: 1.0000, l2: 0.01307, Time: 69.11s
# It: 2200 [PARAMS:ON|PHYS:ON], Loss: 3.963e-03, l1: 1.0000, l2: 0.01295, Time: 69.82s
# It: 2300 [PARAMS:ON|PHYS:ON], Loss: 3.915e-03, l1: 1.0000, l2: 0.01281, Time: 70.30s
# It: 2400 [PARAMS:ON|PHYS:ON], Loss: 3.425e-03, l1: 1.0000, l2: 0.01268, Time: 70.35s
# It: 2500 [PARAMS:ON|PHYS:ON], Loss: 3.221e-03, l1: 1.0000, l2: 0.01259, Time: 70.22s
# It: 2600 [PARAMS:ON|PHYS:ON], Loss: 3.183e-03, l1: 1.0000, l2: 0.01249, Time: 70.19s
# It: 2700 [PARAMS:ON|PHYS:ON], Loss: 3.621e-03, l1: 1.0000, l2: 0.01246, Time: 70.16s
# It: 2800 [PARAMS:ON|PHYS:ON], Loss: 2.898e-03, l1: 1.0000, l2: 0.01235, Time: 70.15s
# It: 2900 [PARAMS:ON|PHYS:ON], Loss: 2.830e-03, l1: 1.0000, l2: 0.01223, Time: 70.21s
# It: 3000 [PARAMS:ON|PHYS:ON], Loss: 2.667e-03, l1: 1.0000, l2: 0.01215, Time: 70.26s
# It: 3100 [PARAMS:ON|PHYS:ON], Loss: 2.830e-03, l1: 1.0000, l2: 0.01212, Time: 70.13s
# It: 3200 [PARAMS:ON|PHYS:ON], Loss: 2.488e-03, l1: 1.0000, l2: 0.01202, Time: 70.28s
# It: 3300 [PARAMS:ON|PHYS:ON], Loss: 2.361e-03, l1: 1.0000, l2: 0.01198, Time: 70.32s
# It: 3400 [PARAMS:ON|PHYS:ON], Loss: 2.416e-03, l1: 1.0000, l2: 0.01190, Time: 70.22s
# It: 3500 [PARAMS:ON|PHYS:ON], Loss: 2.299e-03, l1: 1.0000, l2: 0.01186, Time: 70.03s
# It: 3600 [PARAMS:ON|PHYS:ON], Loss: 2.486e-03, l1: 1.0000, l2: 0.01185, Time: 70.49s
# It: 3700 [PARAMS:ON|PHYS:ON], Loss: 2.050e-03, l1: 1.0000, l2: 0.01176, Time: 70.14s
# It: 3800 [PARAMS:ON|PHYS:ON], Loss: 2.578e-03, l1: 1.0000, l2: 0.01180, Time: 70.10s
# It: 3900 [PARAMS:ON|PHYS:ON], Loss: 2.068e-03, l1: 1.0000, l2: 0.01174, Time: 70.30s
# It: 4000 [PARAMS:ON|PHYS:ON], Loss: 2.074e-03, l1: 1.0000, l2: 0.01171, Time: 70.13s
# It: 4100 [PARAMS:ON|PHYS:ON], Loss: 2.111e-03, l1: 1.0000, l2: 0.01155, Time: 70.28s
# It: 4200 [PARAMS:ON|PHYS:ON], Loss: 1.811e-03, l1: 1.0000, l2: 0.01157, Time: 70.42s
# It: 4300 [PARAMS:ON|PHYS:ON], Loss: 1.746e-03, l1: 1.0000, l2: 0.01161, Time: 70.23s
# It: 4400 [PARAMS:ON|PHYS:ON], Loss: 1.852e-03, l1: 1.0000, l2: 0.01160, Time: 70.19s
# It: 4500 [PARAMS:ON|PHYS:ON], Loss: 1.699e-03, l1: 1.0000, l2: 0.01155, Time: 69.96s
# It: 4600 [PARAMS:ON|PHYS:ON], Loss: 2.271e-03, l1: 1.0000, l2: 0.01153, Time: 70.42s
# It: 4700 [PARAMS:ON|PHYS:ON], Loss: 1.615e-03, l1: 1.0000, l2: 0.01149, Time: 70.20s
# It: 4800 [PARAMS:ON|PHYS:ON], Loss: 1.409e-03, l1: 1.0000, l2: 0.01153, Time: 70.65s
# It: 4900 [PARAMS:ON|PHYS:ON], Loss: 1.371e-03, l1: 1.0000, l2: 0.01150, Time: 70.08s
# It: 5000 [PARAMS:ON|PHYS:ON], Loss: 1.351e-03, l1: 1.0000, l2: 0.01148, Time: 70.54s
# It: 5100 [PARAMS:ON|PHYS:ON], Loss: 2.060e-03, l1: 1.0000, l2: 0.01156, Time: 70.42s
# It: 5200 [PARAMS:ON|PHYS:ON], Loss: 2.539e-03, l1: 1.0000, l2: 0.01156, Time: 70.11s
# It: 5300 [PARAMS:ON|PHYS:ON], Loss: 1.506e-03, l1: 1.0000, l2: 0.01150, Time: 70.43s
# It: 5400 [PARAMS:ON|PHYS:ON], Loss: 1.239e-03, l1: 1.0000, l2: 0.01144, Time: 70.25s
# It: 5500 [PARAMS:ON|PHYS:ON], Loss: 1.813e-03, l1: 1.0000, l2: 0.01142, Time: 70.34s
# It: 5600 [PARAMS:ON|PHYS:ON], Loss: 1.190e-03, l1: 1.0000, l2: 0.01140, Time: 70.41s
# It: 5700 [PARAMS:ON|PHYS:ON], Loss: 1.664e-03, l1: 1.0000, l2: 0.01153, Time: 70.31s
# It: 5800 [PARAMS:ON|PHYS:ON], Loss: 1.152e-03, l1: 1.0000, l2: 0.01139, Time: 70.37s
# It: 5900 [PARAMS:ON|PHYS:ON], Loss: 1.262e-03, l1: 1.0000, l2: 0.01139, Time: 70.18s
# It: 6000 [PARAMS:ON|PHYS:ON], Loss: 1.102e-03, l1: 1.0000, l2: 0.01135, Time: 70.44s
# It: 6100 [PARAMS:ON|PHYS:ON], Loss: 1.085e-03, l1: 1.0000, l2: 0.01137, Time: 70.20s
# It: 6200 [PARAMS:ON|PHYS:ON], Loss: 1.174e-03, l1: 1.0000, l2: 0.01135, Time: 70.28s
# It: 6300 [PARAMS:ON|PHYS:ON], Loss: 1.082e-03, l1: 1.0000, l2: 0.01131, Time: 70.29s
# It: 6400 [PARAMS:ON|PHYS:ON], Loss: 1.171e-03, l1: 1.0000, l2: 0.01132, Time: 70.22s
# It: 6500 [PARAMS:ON|PHYS:ON], Loss: 1.029e-03, l1: 1.0000, l2: 0.01132, Time: 70.49s
# It: 6600 [PARAMS:ON|PHYS:ON], Loss: 1.034e-03, l1: 1.0000, l2: 0.01133, Time: 70.19s
# It: 6700 [PARAMS:ON|PHYS:ON], Loss: 2.317e-03, l1: 1.0000, l2: 0.01146, Time: 70.07s
# It: 6800 [PARAMS:ON|PHYS:ON], Loss: 1.054e-03, l1: 1.0000, l2: 0.01132, Time: 70.33s
# It: 6900 [PARAMS:ON|PHYS:ON], Loss: 1.017e-03, l1: 1.0000, l2: 0.01131, Time: 70.40s
# It: 7000 [PARAMS:ON|PHYS:ON], Loss: 9.994e-04, l1: 1.0000, l2: 0.01129, Time: 70.35s
# It: 7100 [PARAMS:ON|PHYS:ON], Loss: 1.046e-03, l1: 1.0000, l2: 0.01128, Time: 70.12s
# It: 7200 [PARAMS:ON|PHYS:ON], Loss: 1.356e-03, l1: 1.0000, l2: 0.01127, Time: 70.27s
# It: 7300 [PARAMS:ON|PHYS:ON], Loss: 9.426e-04, l1: 1.0000, l2: 0.01125, Time: 70.40s
# It: 7400 [PARAMS:ON|PHYS:ON], Loss: 1.000e-03, l1: 1.0000, l2: 0.01124, Time: 70.18s
# It: 7500 [PARAMS:ON|PHYS:ON], Loss: 1.109e-03, l1: 1.0000, l2: 0.01122, Time: 70.35s
# It: 7600 [PARAMS:ON|PHYS:ON], Loss: 9.805e-04, l1: 1.0000, l2: 0.01121, Time: 70.24s
# It: 7700 [PARAMS:ON|PHYS:ON], Loss: 9.587e-04, l1: 1.0000, l2: 0.01121, Time: 70.24s
# It: 7800 [PARAMS:ON|PHYS:ON], Loss: 1.035e-03, l1: 1.0000, l2: 0.01126, Time: 70.50s
# It: 7900 [PARAMS:ON|PHYS:ON], Loss: 9.330e-04, l1: 1.0000, l2: 0.01122, Time: 70.47s
# It: 8000 [PARAMS:ON|PHYS:ON], Loss: 9.654e-04, l1: 1.0000, l2: 0.01124, Time: 70.31s
# It: 8100 [PARAMS:ON|PHYS:ON], Loss: 8.807e-04, l1: 1.0000, l2: 0.01123, Time: 70.15s
# It: 8200 [PARAMS:ON|PHYS:ON], Loss: 8.393e-04, l1: 1.0000, l2: 0.01120, Time: 70.22s
# It: 8300 [PARAMS:ON|PHYS:ON], Loss: 8.369e-04, l1: 1.0000, l2: 0.01119, Time: 70.25s
# It: 8400 [PARAMS:ON|PHYS:ON], Loss: 9.410e-04, l1: 1.0000, l2: 0.01124, Time: 70.25s
# It: 8500 [PARAMS:ON|PHYS:ON], Loss: 1.122e-03, l1: 1.0000, l2: 0.01121, Time: 70.17s
# It: 8600 [PARAMS:ON|PHYS:ON], Loss: 8.402e-04, l1: 1.0000, l2: 0.01117, Time: 70.24s
# It: 8700 [PARAMS:ON|PHYS:ON], Loss: 1.177e-03, l1: 1.0000, l2: 0.01112, Time: 70.40s
# It: 8800 [PARAMS:ON|PHYS:ON], Loss: 8.330e-04, l1: 1.0000, l2: 0.01115, Time: 70.37s
# It: 8900 [PARAMS:ON|PHYS:ON], Loss: 1.495e-03, l1: 1.0000, l2: 0.01108, Time: 70.28s
# It: 9000 [PARAMS:ON|PHYS:ON], Loss: 1.134e-03, l1: 1.0000, l2: 0.01108, Time: 70.27s
# It: 9100 [PARAMS:ON|PHYS:ON], Loss: 8.212e-04, l1: 1.0000, l2: 0.01115, Time: 70.29s
# It: 9200 [PARAMS:ON|PHYS:ON], Loss: 8.128e-04, l1: 1.0000, l2: 0.01112, Time: 70.33s
# It: 9300 [PARAMS:ON|PHYS:ON], Loss: 8.104e-04, l1: 1.0000, l2: 0.01116, Time: 70.37s
# It: 9400 [PARAMS:ON|PHYS:ON], Loss: 7.623e-04, l1: 1.0000, l2: 0.01110, Time: 70.34s
# It: 9500 [PARAMS:ON|PHYS:ON], Loss: 8.059e-04, l1: 1.0000, l2: 0.01114, Time: 70.26s
# It: 9600 [PARAMS:ON|PHYS:ON], Loss: 7.534e-04, l1: 1.0000, l2: 0.01109, Time: 70.28s
# It: 9700 [PARAMS:ON|PHYS:ON], Loss: 1.125e-03, l1: 1.0000, l2: 0.01109, Time: 70.53s
# It: 9800 [PARAMS:ON|PHYS:ON], Loss: 2.144e-03, l1: 1.0000, l2: 0.01109, Time: 70.39s
# It: 9900 [PARAMS:ON|PHYS:ON], Loss: 2.193e-03, l1: 1.0000, l2: 0.01111, Time: 71.37s
# It: 10000 [PARAMS:ON|PHYS:ON], Loss: 7.717e-04, l1: 1.0000, l2: 0.01105, Time: 70.33s
# It: 10100 [PARAMS:ON|PHYS:ON], Loss: 7.296e-04, l1: 1.0000, l2: 0.01105, Time: 70.50s
# It: 10200 [PARAMS:ON|PHYS:ON], Loss: 7.265e-04, l1: 1.0000, l2: 0.01107, Time: 70.39s
# It: 10300 [PARAMS:ON|PHYS:ON], Loss: 8.624e-04, l1: 1.0000, l2: 0.01111, Time: 70.11s
# It: 10400 [PARAMS:ON|PHYS:ON], Loss: 7.155e-04, l1: 1.0000, l2: 0.01106, Time: 70.44s
# It: 10500 [PARAMS:ON|PHYS:ON], Loss: 7.398e-04, l1: 1.0000, l2: 0.01106, Time: 70.13s
# It: 10600 [PARAMS:ON|PHYS:ON], Loss: 7.164e-04, l1: 1.0000, l2: 0.01105, Time: 70.39s
# It: 10700 [PARAMS:ON|PHYS:ON], Loss: 7.768e-04, l1: 1.0000, l2: 0.01104, Time: 70.24s
# It: 10800 [PARAMS:ON|PHYS:ON], Loss: 8.431e-04, l1: 1.0000, l2: 0.01103, Time: 70.31s
# It: 10900 [PARAMS:ON|PHYS:ON], Loss: 1.381e-03, l1: 1.0000, l2: 0.01111, Time: 70.27s
# It: 11000 [PARAMS:ON|PHYS:ON], Loss: 7.302e-04, l1: 1.0000, l2: 0.01104, Time: 70.26s
# It: 11100 [PARAMS:ON|PHYS:ON], Loss: 6.762e-04, l1: 1.0000, l2: 0.01102, Time: 70.43s
# It: 11200 [PARAMS:ON|PHYS:ON], Loss: 6.742e-04, l1: 1.0000, l2: 0.01101, Time: 70.10s
# It: 11300 [PARAMS:ON|PHYS:ON], Loss: 6.907e-04, l1: 1.0000, l2: 0.01102, Time: 70.38s
# It: 11400 [PARAMS:ON|PHYS:ON], Loss: 6.630e-04, l1: 1.0000, l2: 0.01100, Time: 70.22s
# It: 11500 [PARAMS:ON|PHYS:ON], Loss: 6.698e-04, l1: 1.0000, l2: 0.01099, Time: 70.29s
# It: 11600 [PARAMS:ON|PHYS:ON], Loss: 7.114e-04, l1: 1.0000, l2: 0.01097, Time: 70.34s
# It: 11700 [PARAMS:ON|PHYS:ON], Loss: 7.418e-04, l1: 1.0000, l2: 0.01102, Time: 70.12s
# It: 11800 [PARAMS:ON|PHYS:ON], Loss: 7.110e-04, l1: 1.0000, l2: 0.01098, Time: 70.38s
# It: 11900 [PARAMS:ON|PHYS:ON], Loss: 6.524e-04, l1: 1.0000, l2: 0.01098, Time: 70.18s
# It: 12000 [PARAMS:ON|PHYS:ON], Loss: 6.467e-04, l1: 1.0000, l2: 0.01097, Time: 70.44s
# It: 12100 [PARAMS:ON|PHYS:ON], Loss: 6.899e-04, l1: 1.0000, l2: 0.01100, Time: 70.49s
# It: 12200 [PARAMS:ON|PHYS:ON], Loss: 9.553e-04, l1: 1.0000, l2: 0.01095, Time: 70.20s
# It: 12300 [PARAMS:ON|PHYS:ON], Loss: 6.919e-04, l1: 1.0000, l2: 0.01098, Time: 70.36s
# It: 12400 [PARAMS:ON|PHYS:ON], Loss: 7.840e-04, l1: 1.0000, l2: 0.01095, Time: 70.30s
# It: 12500 [PARAMS:ON|PHYS:ON], Loss: 6.411e-04, l1: 1.0000, l2: 0.01094, Time: 70.55s
# It: 12600 [PARAMS:ON|PHYS:ON], Loss: 1.044e-03, l1: 1.0000, l2: 0.01094, Time: 70.19s
# It: 12700 [PARAMS:ON|PHYS:ON], Loss: 6.407e-04, l1: 1.0000, l2: 0.01095, Time: 70.36s
# It: 12800 [PARAMS:ON|PHYS:ON], Loss: 6.481e-04, l1: 1.0000, l2: 0.01095, Time: 70.32s
# It: 12900 [PARAMS:ON|PHYS:ON], Loss: 6.769e-04, l1: 1.0000, l2: 0.01096, Time: 70.26s
# It: 13000 [PARAMS:ON|PHYS:ON], Loss: 6.769e-04, l1: 1.0000, l2: 0.01098, Time: 70.33s
# It: 13100 [PARAMS:ON|PHYS:ON], Loss: 6.233e-04, l1: 1.0000, l2: 0.01093, Time: 70.21s
# It: 13200 [PARAMS:ON|PHYS:ON], Loss: 8.249e-04, l1: 1.0000, l2: 0.01092, Time: 70.27s
# It: 13300 [PARAMS:ON|PHYS:ON], Loss: 7.800e-04, l1: 1.0000, l2: 0.01091, Time: 70.25s
# It: 13400 [PARAMS:ON|PHYS:ON], Loss: 6.818e-04, l1: 1.0000, l2: 0.01089, Time: 70.31s
# It: 13500 [PARAMS:ON|PHYS:ON], Loss: 6.125e-04, l1: 1.0000, l2: 0.01092, Time: 70.22s
# It: 13600 [PARAMS:ON|PHYS:ON], Loss: 6.187e-04, l1: 1.0000, l2: 0.01092, Time: 70.21s
# It: 13700 [PARAMS:ON|PHYS:ON], Loss: 6.214e-04, l1: 1.0000, l2: 0.01089, Time: 70.26s
# It: 13800 [PARAMS:ON|PHYS:ON], Loss: 6.738e-04, l1: 1.0000, l2: 0.01092, Time: 70.28s
# It: 13900 [PARAMS:ON|PHYS:ON], Loss: 6.749e-04, l1: 1.0000, l2: 0.01087, Time: 70.33s
# It: 14000 [PARAMS:ON|PHYS:ON], Loss: 6.218e-04, l1: 1.0000, l2: 0.01089, Time: 70.44s
# It: 14100 [PARAMS:ON|PHYS:ON], Loss: 8.354e-04, l1: 1.0000, l2: 0.01096, Time: 70.16s
# It: 14200 [PARAMS:ON|PHYS:ON], Loss: 6.428e-04, l1: 1.0000, l2: 0.01088, Time: 70.36s
# It: 14300 [PARAMS:ON|PHYS:ON], Loss: 6.203e-04, l1: 1.0000, l2: 0.01087, Time: 70.21s
# It: 14400 [PARAMS:ON|PHYS:ON], Loss: 6.404e-04, l1: 1.0000, l2: 0.01089, Time: 70.53s
# It: 14500 [PARAMS:ON|PHYS:ON], Loss: 1.078e-03, l1: 1.0000, l2: 0.01097, Time: 70.36s
# It: 14600 [PARAMS:ON|PHYS:ON], Loss: 7.307e-04, l1: 1.0000, l2: 0.01091, Time: 70.16s
# It: 14700 [PARAMS:ON|PHYS:ON], Loss: 7.575e-04, l1: 1.0000, l2: 0.01084, Time: 70.22s
# It: 14800 [PARAMS:ON|PHYS:ON], Loss: 1.399e-03, l1: 1.0000, l2: 0.01081, Time: 70.14s
# It: 14900 [PARAMS:ON|PHYS:ON], Loss: 6.117e-04, l1: 1.0000, l2: 0.01087, Time: 70.46s
# It: 15000 [PARAMS:ON|PHYS:ON], Loss: 7.472e-04, l1: 1.0000, l2: 0.01090, Time: 70.53s
# It: 15100 [PARAMS:ON|PHYS:ON], Loss: 6.194e-04, l1: 1.0000, l2: 0.01087, Time: 70.33s
# It: 15200 [PARAMS:ON|PHYS:ON], Loss: 9.613e-04, l1: 1.0000, l2: 0.01088, Time: 70.25s
# It: 15300 [PARAMS:ON|PHYS:ON], Loss: 5.683e-04, l1: 1.0000, l2: 0.01085, Time: 70.44s
# It: 15400 [PARAMS:ON|PHYS:ON], Loss: 5.955e-04, l1: 1.0000, l2: 0.01083, Time: 70.46s
# It: 15500 [PARAMS:ON|PHYS:ON], Loss: 1.368e-03, l1: 1.0000, l2: 0.01097, Time: 70.13s
# It: 15600 [PARAMS:ON|PHYS:ON], Loss: 8.937e-04, l1: 1.0000, l2: 0.01077, Time: 70.25s
# It: 15700 [PARAMS:ON|PHYS:ON], Loss: 5.664e-04, l1: 1.0000, l2: 0.01086, Time: 70.24s
# It: 15800 [PARAMS:ON|PHYS:ON], Loss: 6.669e-04, l1: 1.0000, l2: 0.01083, Time: 70.20s
# It: 15900 [PARAMS:ON|PHYS:ON], Loss: 6.048e-04, l1: 1.0000, l2: 0.01081, Time: 70.38s
# It: 16000 [PARAMS:ON|PHYS:ON], Loss: 5.633e-04, l1: 1.0000, l2: 0.01084, Time: 70.31s
# It: 16100 [PARAMS:ON|PHYS:ON], Loss: 7.459e-04, l1: 1.0000, l2: 0.01088, Time: 70.53s
# It: 16200 [PARAMS:ON|PHYS:ON], Loss: 5.581e-04, l1: 1.0000, l2: 0.01083, Time: 70.37s
# It: 16300 [PARAMS:ON|PHYS:ON], Loss: 5.615e-04, l1: 1.0000, l2: 0.01081, Time: 70.34s
# It: 16400 [PARAMS:ON|PHYS:ON], Loss: 6.918e-04, l1: 1.0000, l2: 0.01080, Time: 70.31s
# It: 16500 [PARAMS:ON|PHYS:ON], Loss: 7.223e-04, l1: 1.0000, l2: 0.01084, Time: 70.11s
# It: 16600 [PARAMS:ON|PHYS:ON], Loss: 5.717e-04, l1: 1.0000, l2: 0.01081, Time: 70.36s
# It: 16700 [PARAMS:ON|PHYS:ON], Loss: 5.388e-04, l1: 1.0000, l2: 0.01081, Time: 70.36s
# It: 16800 [PARAMS:ON|PHYS:ON], Loss: 5.378e-04, l1: 1.0000, l2: 0.01081, Time: 70.41s
# It: 16900 [PARAMS:ON|PHYS:ON], Loss: 5.571e-04, l1: 1.0000, l2: 0.01082, Time: 70.23s
# It: 17000 [PARAMS:ON|PHYS:ON], Loss: 7.445e-04, l1: 1.0000, l2: 0.01077, Time: 70.31s
# It: 17100 [PARAMS:ON|PHYS:ON], Loss: 5.492e-04, l1: 1.0000, l2: 0.01082, Time: 70.46s
# It: 17200 [PARAMS:ON|PHYS:ON], Loss: 5.587e-04, l1: 1.0000, l2: 0.01081, Time: 70.31s
# It: 17300 [PARAMS:ON|PHYS:ON], Loss: 5.696e-04, l1: 1.0000, l2: 0.01080, Time: 70.38s
# It: 17400 [PARAMS:ON|PHYS:ON], Loss: 6.052e-04, l1: 1.0000, l2: 0.01082, Time: 70.27s
# It: 17500 [PARAMS:ON|PHYS:ON], Loss: 6.765e-04, l1: 1.0000, l2: 0.01083, Time: 70.45s
# It: 17600 [PARAMS:ON|PHYS:ON], Loss: 5.683e-04, l1: 1.0000, l2: 0.01083, Time: 70.32s
# It: 17700 [PARAMS:ON|PHYS:ON], Loss: 1.256e-03, l1: 1.0000, l2: 0.01089, Time: 70.44s
# It: 17800 [PARAMS:ON|PHYS:ON], Loss: 6.527e-04, l1: 1.0000, l2: 0.01080, Time: 70.39s
# It: 17900 [PARAMS:ON|PHYS:ON], Loss: 5.261e-04, l1: 1.0000, l2: 0.01079, Time: 70.32s
# It: 18000 [PARAMS:ON|PHYS:ON], Loss: 5.530e-04, l1: 1.0000, l2: 0.01079, Time: 70.51s
# It: 18100 [PARAMS:ON|PHYS:ON], Loss: 6.312e-04, l1: 1.0000, l2: 0.01082, Time: 70.45s
# It: 18200 [PARAMS:ON|PHYS:ON], Loss: 5.445e-04, l1: 1.0000, l2: 0.01077, Time: 70.25s
# It: 18300 [PARAMS:ON|PHYS:ON], Loss: 2.649e-03, l1: 1.0000, l2: 0.01069, Time: 70.37s
# It: 18400 [PARAMS:ON|PHYS:ON], Loss: 5.338e-04, l1: 1.0000, l2: 0.01078, Time: 70.44s
# It: 18500 [PARAMS:ON|PHYS:ON], Loss: 6.299e-04, l1: 1.0000, l2: 0.01075, Time: 70.50s
# It: 18600 [PARAMS:ON|PHYS:ON], Loss: 5.287e-04, l1: 1.0000, l2: 0.01079, Time: 70.47s
# It: 18700 [PARAMS:ON|PHYS:ON], Loss: 5.402e-04, l1: 1.0000, l2: 0.01076, Time: 70.31s
# It: 18800 [PARAMS:ON|PHYS:ON], Loss: 5.238e-04, l1: 1.0000, l2: 0.01078, Time: 70.32s
# It: 18900 [PARAMS:ON|PHYS:ON], Loss: 5.171e-04, l1: 1.0000, l2: 0.01077, Time: 70.31s
# It: 19000 [PARAMS:ON|PHYS:ON], Loss: 7.265e-04, l1: 1.0000, l2: 0.01073, Time: 70.37s
# It: 19100 [PARAMS:ON|PHYS:ON], Loss: 5.670e-04, l1: 1.0000, l2: 0.01076, Time: 70.35s
# It: 19200 [PARAMS:ON|PHYS:ON], Loss: 6.049e-04, l1: 1.0000, l2: 0.01074, Time: 70.44s
# It: 19300 [PARAMS:ON|PHYS:ON], Loss: 8.156e-04, l1: 1.0000, l2: 0.01071, Time: 70.52s
# It: 19400 [PARAMS:ON|PHYS:ON], Loss: 1.088e-03, l1: 1.0000, l2: 0.01077, Time: 70.35s
# It: 19500 [PARAMS:ON|PHYS:ON], Loss: 5.851e-04, l1: 1.0000, l2: 0.01073, Time: 70.39s
# It: 19600 [PARAMS:ON|PHYS:ON], Loss: 5.116e-04, l1: 1.0000, l2: 0.01076, Time: 70.29s
# It: 19700 [PARAMS:ON|PHYS:ON], Loss: 6.233e-04, l1: 1.0000, l2: 0.01077, Time: 70.37s
# It: 19800 [PARAMS:ON|PHYS:ON], Loss: 4.993e-04, l1: 1.0000, l2: 0.01075, Time: 70.22s
# It: 19900 [PARAMS:ON|PHYS:ON], Loss: 5.943e-04, l1: 1.0000, l2: 0.01079, Time: 70.47s
# It: 20000 [PARAMS:ON|PHYS:ON], Loss: 5.121e-04, l1: 1.0000, l2: 0.01076, Time: 70.51s
# It: 20100 [PARAMS:ON|PHYS:ON], Loss: 7.924e-04, l1: 1.0000, l2: 0.01072, Time: 70.76s
# It: 20200 [PARAMS:ON|PHYS:ON], Loss: 7.092e-04, l1: 1.0000, l2: 0.01081, Time: 70.32s
# It: 20300 [PARAMS:ON|PHYS:ON], Loss: 5.161e-04, l1: 1.0000, l2: 0.01076, Time: 70.24s
# It: 20400 [PARAMS:ON|PHYS:ON], Loss: 5.191e-04, l1: 1.0000, l2: 0.01074, Time: 70.54s
# It: 20500 [PARAMS:ON|PHYS:ON], Loss: 1.198e-03, l1: 1.0000, l2: 0.01089, Time: 70.46s
# It: 20600 [PARAMS:ON|PHYS:ON], Loss: 5.065e-04, l1: 1.0000, l2: 0.01076, Time: 70.43s
# It: 20700 [PARAMS:ON|PHYS:ON], Loss: 7.156e-04, l1: 1.0000, l2: 0.01073, Time: 70.14s
# It: 20800 [PARAMS:ON|PHYS:ON], Loss: 5.298e-04, l1: 1.0000, l2: 0.01074, Time: 70.28s
# It: 20900 [PARAMS:ON|PHYS:ON], Loss: 5.212e-04, l1: 1.0000, l2: 0.01072, Time: 70.46s
# It: 21000 [PARAMS:ON|PHYS:ON], Loss: 4.922e-04, l1: 1.0000, l2: 0.01076, Time: 70.39s
# It: 21100 [PARAMS:ON|PHYS:ON], Loss: 5.182e-04, l1: 1.0000, l2: 0.01073, Time: 70.25s
# It: 21200 [PARAMS:ON|PHYS:ON], Loss: 6.503e-04, l1: 1.0000, l2: 0.01069, Time: 70.48s
# It: 21300 [PARAMS:ON|PHYS:ON], Loss: 5.214e-04, l1: 1.0000, l2: 0.01072, Time: 70.39s
# It: 21400 [PARAMS:ON|PHYS:ON], Loss: 5.032e-04, l1: 1.0000, l2: 0.01073, Time: 70.52s
# It: 21500 [PARAMS:ON|PHYS:ON], Loss: 4.960e-04, l1: 1.0000, l2: 0.01075, Time: 70.14s
# It: 21600 [PARAMS:ON|PHYS:ON], Loss: 4.924e-04, l1: 1.0000, l2: 0.01073, Time: 70.29s
# It: 21700 [PARAMS:ON|PHYS:ON], Loss: 5.136e-04, l1: 1.0000, l2: 0.01075, Time: 70.42s
# It: 21800 [PARAMS:ON|PHYS:ON], Loss: 4.963e-04, l1: 1.0000, l2: 0.01073, Time: 70.44s
# It: 21900 [PARAMS:ON|PHYS:ON], Loss: 5.144e-04, l1: 1.0000, l2: 0.01071, Time: 70.52s
# It: 22000 [PARAMS:ON|PHYS:ON], Loss: 5.567e-04, l1: 1.0000, l2: 0.01072, Time: 70.31s
# It: 22100 [PARAMS:ON|PHYS:ON], Loss: 6.252e-04, l1: 1.0000, l2: 0.01072, Time: 70.34s
# It: 22200 [PARAMS:ON|PHYS:ON], Loss: 5.068e-04, l1: 1.0000, l2: 0.01074, Time: 70.32s
# It: 22300 [PARAMS:ON|PHYS:ON], Loss: 5.830e-04, l1: 1.0000, l2: 0.01073, Time: 70.54s
# It: 22400 [PARAMS:ON|PHYS:ON], Loss: 5.079e-04, l1: 1.0000, l2: 0.01071, Time: 70.40s
# It: 22500 [PARAMS:ON|PHYS:ON], Loss: 4.780e-04, l1: 1.0000, l2: 0.01073, Time: 70.22s
# It: 22600 [PARAMS:ON|PHYS:ON], Loss: 4.811e-04, l1: 1.0000, l2: 0.01072, Time: 70.49s
# It: 22700 [PARAMS:ON|PHYS:ON], Loss: 5.378e-04, l1: 1.0000, l2: 0.01073, Time: 70.71s
# It: 22800 [PARAMS:ON|PHYS:ON], Loss: 4.743e-04, l1: 1.0000, l2: 0.01072, Time: 70.39s
# It: 22900 [PARAMS:ON|PHYS:ON], Loss: 7.006e-04, l1: 1.0000, l2: 0.01077, Time: 70.44s
# It: 23000 [PARAMS:ON|PHYS:ON], Loss: 5.984e-04, l1: 1.0000, l2: 0.01072, Time: 70.55s
# It: 23100 [PARAMS:ON|PHYS:ON], Loss: 4.797e-04, l1: 1.0000, l2: 0.01070, Time: 70.41s
# It: 23200 [PARAMS:ON|PHYS:ON], Loss: 4.733e-04, l1: 1.0000, l2: 0.01074, Time: 70.45s
# It: 23300 [PARAMS:ON|PHYS:ON], Loss: 6.438e-04, l1: 1.0000, l2: 0.01078, Time: 70.29s
# It: 23400 [PARAMS:ON|PHYS:ON], Loss: 8.315e-04, l1: 1.0000, l2: 0.01078, Time: 70.28s
# It: 23500 [PARAMS:ON|PHYS:ON], Loss: 5.433e-04, l1: 1.0000, l2: 0.01074, Time: 70.51s
# It: 23600 [PARAMS:ON|PHYS:ON], Loss: 9.566e-04, l1: 1.0000, l2: 0.01065, Time: 70.32s
# It: 23700 [PARAMS:ON|PHYS:ON], Loss: 6.060e-04, l1: 1.0000, l2: 0.01075, Time: 70.53s
# It: 23800 [PARAMS:ON|PHYS:ON], Loss: 4.930e-04, l1: 1.0000, l2: 0.01071, Time: 70.29s
# It: 23900 [PARAMS:ON|PHYS:ON], Loss: 4.933e-04, l1: 1.0000, l2: 0.01072, Time: 70.31s
# It: 24000 [PARAMS:ON|PHYS:ON], Loss: 4.930e-04, l1: 1.0000, l2: 0.01073, Time: 70.42s
# It: 24100 [PARAMS:ON|PHYS:ON], Loss: 4.806e-04, l1: 1.0000, l2: 0.01070, Time: 70.45s
# It: 24200 [PARAMS:ON|PHYS:ON], Loss: 4.638e-04, l1: 1.0000, l2: 0.01070, Time: 70.35s
# It: 24300 [PARAMS:ON|PHYS:ON], Loss: 5.678e-04, l1: 1.0000, l2: 0.01073, Time: 70.41s
# It: 24400 [PARAMS:ON|PHYS:ON], Loss: 4.866e-04, l1: 1.0000, l2: 0.01072, Time: 70.34s
# It: 24500 [PARAMS:ON|PHYS:ON], Loss: 4.665e-04, l1: 1.0000, l2: 0.01070, Time: 70.51s
# It: 24600 [PARAMS:ON|PHYS:ON], Loss: 4.979e-04, l1: 1.0000, l2: 0.01073, Time: 70.32s
# It: 24700 [PARAMS:ON|PHYS:ON], Loss: 5.156e-04, l1: 1.0000, l2: 0.01073, Time: 70.36s
# It: 24800 [PARAMS:ON|PHYS:ON], Loss: 8.015e-04, l1: 1.0000, l2: 0.01079, Time: 70.43s
# It: 24900 [PARAMS:ON|PHYS:ON], Loss: 5.244e-04, l1: 1.0000, l2: 0.01070, Time: 70.33s
# Done!

# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator  
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata
from matplotlib.colors import TwoSlopeNorm
import matplotlib.ticker as ticker
import os

# %%
# Visual setup
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["STIXGeneral"],
    "mathtext.fontset": "stix",
    "font.size": 16
})

def plot_3d_surface(X, Y, Z, z_label, x_train, y_train, fig_size=(9, 8), plot_title=None, vmin=None, vmax=None, norm=None, ticks=None):
    """Función modular para graficar superficies 3D con normalización específica."""
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    
    surf = ax.plot_surface(X, Y, Z, cmap='coolwarm', alpha=0.9, edgecolor='none', 
                           vmin=vmin, vmax=vmax, norm=norm)

    if plot_title:
        ax.set_title(plot_title, fontsize=20, pad=15)
    
    # Axis configuration
    z_min = np.min(Z) - 0.2
    ax.set_zlim(z_min, np.max(Z))
    ax.scatter(x_train, y_train, np.full_like(x_train, z_min), c='k', marker='.', s=1, alpha=0.2)
    
    # Z-axis tick reduction to prevent saturation
    ax.zaxis.set_major_locator(MaxNLocator(nbins=4)) 
    
    ax.view_init(elev=35, azim=45)
    ax.set_xlabel('$x$', fontsize=18, labelpad=10)
    ax.set_ylabel('$y$', fontsize=18, labelpad=10)
    ax.set_zlabel(z_label, fontsize=18, rotation=0, labelpad=20)
    ax.set_box_aspect((2.5, 1.5, 0.5))
    
    # Color bar
    cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=15, pad=0.1, ticks=ticks)
    label_text = z_label.replace('$','').split('(')[0] 
    cbar.set_label(f'${label_text}$', rotation=0, labelpad=15, fontsize=16)
    
    return fig

# %%
if __name__ == "__main__": 
    # Routes
    DATA_PATH = '../Data/cylinder_nektar_wake.mat'
    RESULTS_PATH = 'Results/Karman/cylinder_results.npz'
    SAVE_DIR = 'Results/Karman'
    os.makedirs(SAVE_DIR, exist_ok=True)
    
    # Load data
    data = scipy.io.loadmat(DATA_PATH)
    results = np.load(RESULTS_PATH)
    
    X_star = data['X_star']
    U_star = data['U_star'] 
    P_star = data['p_star']
    t_star = data['t'].flatten() 

    snap = int(results['snap'])
    current_time = t_star[snap]

    print(f"--- SNAPSHOT INFO ---")
    print(f"Snapshot index: {snap}")
    print(f"Physical time (t): {current_time:.4f}")
    
    u_pred = results['u_pred']
    v_pred = results['v_pred']
    p_pred = results['p_pred']
    snap = int(results['snap'])

    x_train = results['x_train']
    y_train = results['y_train']
    
    # Prepare Mesh
    lb = np.array([X_star[:,0].min(), X_star[:,1].min()])
    ub = np.array([X_star[:,0].max(), X_star[:,1].max()])
    nn_x, nn_y = 400, 150
    x_plot = np.linspace(lb[0], ub[0], nn_x)
    y_plot = np.linspace(lb[1], ub[1], nn_y)
    X, Y = np.meshgrid(x_plot, y_plot)

    # Metrics
    p_exact = P_star[:, snap]
    u_exact = U_star[:, 0, snap]
    v_exact = U_star[:, 1, snap]

    error_u = np.linalg.norm(u_exact.flatten() - u_pred.flatten(), 2) / np.linalg.norm(u_exact.flatten(), 2)
    error_v = np.linalg.norm(v_exact.flatten() - v_pred.flatten(), 2) / np.linalg.norm(v_exact.flatten(), 2)

    # Pressure centering for relative error calculation
    p_pred_centered = p_pred.flatten() - np.mean(p_pred.flatten())
    p_exact_centered = p_exact.flatten() - np.mean(p_exact.flatten())

    error_p = np.linalg.norm(p_exact_centered - p_pred_centered, 2) / np.linalg.norm(p_exact_centered, 2)

    print(f"\n--- PERFORMANCE METRICS ---")
    print(f"Relative L2 (U): {error_u:.4e}")
    print(f"Relative L2 (V): {error_v:.4e}")
    print(f"Relative L2 (P): {error_p:.4e}")

    # Min and max values
    p_pred_min, p_pred_max = np.min(p_pred), np.max(p_pred)
    p_exact_min, p_exact_max = np.min(p_exact), np.max(p_exact)

    print(f"\n--- PRESSURE RANGES ---")    
    print(f"Predicted Pressure (PINN) | Min: {p_pred_min:.4f}, Max: {p_pred_max:.4f}, Range: {p_pred_max - p_pred_min:.4f}")
    print(f"Exact Pressure            | Min: {p_exact_min:.4f}, Max: {p_exact_max:.4f}, Range: {p_exact_max - p_exact_min:.4f}")
    
    # Interpolation
    UU_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    VV_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')
    PP_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    U_exact_grid = griddata(X_star, u_exact.flatten(), (X, Y), method='cubic')
    V_exact_grid = griddata(X_star, v_exact.flatten(), (X, Y), method='cubic')
    P_exact = griddata(X_star, P_star[:, snap].flatten(), (X, Y), method='cubic')

    # Derivatives (Vorticity)
    dU_dy, dU_dx = np.gradient(griddata(X_star, U_star[:, 0, snap].flatten(), (X, Y), method='cubic'), y_plot, x_plot)
    dV_dy, dV_dx = np.gradient(griddata(X_star, U_star[:, 1, snap].flatten(), (X, Y), method='cubic'), y_plot, x_plot)
    W_exact = dV_dx - dU_dy
    
    dV_dy_p, dV_dx_p = np.gradient(VV_star, y_plot, x_plot)
    dU_dy_p, dU_dx_p = np.gradient(UU_star, y_plot, x_plot)
    W_pred = dV_dx_p - dU_dy_p

    # Mask
    mask = (X**2 + Y**2) <= (0.5)**2
    for var in [UU_star, VV_star, PP_star, P_exact, W_pred, W_exact]:
        var[mask] = np.nan
    
    # Plotting velocities (3D)
    vmin_u = min(np.min(U_exact_grid), np.min(UU_star))
    vmax_u = max(np.max(U_exact_grid), np.max(UU_star))
    norm_u = TwoSlopeNorm(vcenter=0, vmin=vmin_u, vmax=vmax_u)
    manual_ticks=[-0.2,0,1]
    
    fig_u = plot_3d_surface(X, Y, UU_star, '$u(x,y)$', x_train, y_train, fig_size=(9, 8), 
                        plot_title="a) $u(x,y,t)$", 
                        vmin=vmin_u, vmax=vmax_u, norm=norm_u, 
                        ticks=manual_ticks)
    
    fig_u.savefig(f'{SAVE_DIR}/Karman_Noisy_U.png', dpi=300, bbox_inches='tight')

    vmin_v = min(np.min(V_exact_grid), np.min(VV_star))
    vmax_v = max(np.max(V_exact_grid), np.max(VV_star))
    norm_v = TwoSlopeNorm(vcenter=0, vmin=vmin_v, vmax=vmax_v)
    
    fig_v = plot_3d_surface(X, Y, VV_star, '$v(x,y)$', x_train, y_train, 
                        plot_title="b) $v(x,y,t)$", 
                        vmin=vmin_v, vmax=vmax_v, norm=norm_v)
    fig_v.savefig(f'{SAVE_DIR}/Karman_Noisy_V.png', dpi=300, bbox_inches='tight')

    # Pressure (2D Plots) 
    fig_p = plt.figure(figsize=(14, 6))
    for i, (data_p, title) in enumerate(zip([P_exact, PP_star], ['a) Presión exacta', 'b) Presión predicha (PINN)'])):
        ax = fig_p.add_subplot(1, 2, i+1)
        h = ax.imshow(data_p, origin='lower', extent=[lb[0], ub[0], lb[1], ub[1]], cmap='coolwarm')
        ax.set_title(title, fontsize=18, pad=15)
        ax.set_xlabel('$x$', fontsize=18); ax.set_ylabel('$y$', fontsize=18, rotation=0, labelpad=5)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.1)
        cbar = fig_p.colorbar(h, cax=cax)
        cbar.ax.set_title('$p$', fontsize=18, pad=15)
    plt.tight_layout()
    plt.savefig(f'{SAVE_DIR}/Karman_Noisy_P.png', dpi=300, bbox_inches='tight')

    # Vorticity (2D Plots)
    fig_w = plt.figure(figsize=(14, 6))
    vmax = np.nanmax(np.abs(W_exact))
    for i, (data_w, title) in enumerate(zip([W_exact, W_pred], ['a) Vorticidad exacta', 'b) Vorticidad predicha (PINN)'])):
        ax = fig_w.add_subplot(1, 2, i+1)
        h = ax.imshow(data_w, origin='lower', extent=[lb[0], ub[0], lb[1], ub[1]], cmap='RdBu_r', vmin=-vmax, vmax=vmax)
        ax.set_title(title, fontsize=18, pad=15)
        ax.set_xlabel('$x$', fontsize=18); ax.set_ylabel('$y$', fontsize=18, rotation=0, labelpad=5)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.1)
        cbar = fig_w.colorbar(h, cax=cax)
        cbar.ax.set_title(r'$\omega$', fontsize=18, pad=15)
    plt.tight_layout()
    plt.savefig(f'{SAVE_DIR}/Karman_Noisy_Vorticity.png', dpi=300, bbox_inches='tight')

    # Discovery Results
    fig_txt = plt.figure(figsize=(10, 3))
    ax_txt = fig_txt.add_subplot(1, 1, 1)
    ax_txt.axis('off')
    txt = "Von-Kármán's Vortex ($Re=100$)\n\n"
    txt += "Correct EDP:\n"
    txt += "    $u_t + (u u_x + v u_y) = -p_x + 0.01(u_{xx} + u_{yy})$\n\n"
    txt += "Predicted EDP (PINN):\n"
    txt += f"    $u_t + (u u_x + v u_y) = -p_x + {results['lambda_2']:.5f}(u_{{xx}} + u_{{yy}})$\n\n"
    ax_txt.text(0.5, 0.5, txt, fontsize=15, family='monospace', ha='center', bbox=dict(facecolor='whitesmoke', boxstyle='round,pad=1'))
    plt.savefig(f'{SAVE_DIR}/Karman_Noisy_Results.png', dpi=300, bbox_inches='tight')

    plt.show()
# Out:
# --- SNAPSHOT INFO ---
# Snapshot index: 90
# Physical time (t): 9.0000
#
# --- PERFORMANCE METRICS ---
# Relative L2 (U): 1.1054e-02
# Relative L2 (V): 1.9772e-02
# Relative L2 (P): 3.1434e-02
#
# --- PRESSURE RANGES ---
# Predicted Pressure (PINN) | Min: -0.1024, Max: 0.4797, Range: 0.5821
# Exact Pressure            | Min: -0.5172, Max: 0.0719, Range: 0.5891
