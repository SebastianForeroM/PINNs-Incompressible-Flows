# %%
# ----------------------------------
# PINN: Taylor-Green Vortex (Re=100)
# ---------------------------------
import scipy.io
import numpy as np
import tensorflow as tf
import sys
import os
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()

sys.path.append(os.path.abspath(os.path.join(current_dir, '..')))
from model import PhysicsInformedNN
# Out:
# 2026-06-28 19:23:26.858841: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-28 19:23:26.871088: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782692606.884015    6609 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782692606.887692    6609 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-28 19:23:26.900641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# ---------------------------------
# Main 1: Train Taylor-Green Vortex
# ---------------------------------

if __name__ == "__main__": 
 
    # Hyperparameters configuration
    N_train = 5000
    layers = [3, 50, 50, 50, 50, 50, 50, 50, 50, 2]
    
    # Load simulation data
    data = scipy.io.loadmat('../Data/taylor_green_data.mat')
    
    U_star = data['U_star'] 
    P_star = data['p_star'] 
    t_star = data['t']      
    X_star = data['X_star'] 

    x_star = X_star[:,0:1]; y_star = X_star[:,1:2]
    N = X_star.shape[0]; T = t_star.shape[0]
    
    # Grid tile and data flattening    
    XX = np.tile(X_star[:,0:1], (1,T)); YY = np.tile(X_star[:,1:2], (1,T)); TT = np.tile(t_star, (1,N)).T 
    UU = U_star[:,0,:]; VV = U_star[:,1,:]; PP = P_star 
    
    x = XX.flatten()[:,None]; y = YY.flatten()[:,None]; t = TT.flatten()[:,None] 
    u = UU.flatten()[:,None]; v = VV.flatten()[:,None]; p = PP.flatten()[:,None] 

    # Domain bounds    
    lb = np.array([x.min(), y.min(), t.min()])
    ub = np.array([x.max(), y.max(), t.max()])
    lb_tf = tf.constant(lb, dtype=tf.float32)
    ub_tf = tf.constant(ub, dtype=tf.float32)

    # Random selection of training points
    idx = np.random.choice(N*T, N_train, replace=False)
    x_train = x[idx,:]; y_train = y[idx,:]; t_train = t[idx,:]
    u_train = u[idx,:]; v_train = v[idx,:]

    # Convert to TensorFlow tensors
    x_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
    y_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)
    t_tf = tf.convert_to_tensor(t_train, dtype=tf.float32)
    u_tf = tf.convert_to_tensor(u_train, dtype=tf.float32)
    v_tf = tf.convert_to_tensor(v_train, dtype=tf.float32)

    # Training
    model = PhysicsInformedNN(layers, lb_tf, ub_tf)
    
    print("   >>> Phase 1: Data Fitting ...")
    model.train(x_tf, y_tf, t_tf, u_tf, v_tf, epochs=3000, train_params=False, physics_weight=0.0)

    model.reset_optimizer()

    print("   >>> Phase 2: Physics Discovery ...")
    model.train(x_tf, y_tf, t_tf, u_tf, v_tf, epochs=10000, train_params=True, physics_weight=1.0)

    # Prediction and Exportation
    snap = 90 
    if snap >= T: snap = T-1

    x_star_test = X_star[:,0:1]
    y_star_test = X_star[:,1:2]
    t_star_test = TT[:, snap] 
    
    x_test_tf = tf.reshape(tf.convert_to_tensor(x_star_test, dtype=tf.float32), [-1, 1])
    y_test_tf = tf.reshape(tf.convert_to_tensor(y_star_test, dtype=tf.float32), [-1, 1])
    t_test_tf = tf.reshape(tf.convert_to_tensor(t_star_test, dtype=tf.float32), [-1, 1])

    # Model prediction
    u_pred_tf, v_pred_tf, p_pred_tf, _, _ = model.net_NS(x_test_tf, y_test_tf, t_test_tf)
    
    u_pred = u_pred_tf.numpy()
    v_pred = v_pred_tf.numpy()
    p_pred = p_pred_tf.numpy()

    # Retrieve identified parameters
    lambda_1_value = model.lambda_1.numpy()[0]
    lambda_2_value = model.lambda_2.numpy()[0]

    # Retrieve loss history
    loss_total = np.array(model.loss_history['total'])
    loss_data = np.array(model.loss_history['data'])
    loss_phys = np.array(model.loss_history['phys'])

    # Save results to compressed .npz file
    np.savez('Results/TaylorGreen/taylor_green_results.npz', 
             u_pred=u_pred, 
             v_pred=v_pred, 
             p_pred=p_pred, 
             lambda_1=lambda_1_value, 
             lambda_2=lambda_2_value,
             x_train=x_train, 
             y_train=y_train,
             snap=snap,
             loss_total=loss_total,
             loss_data=loss_data,
             loss_phys=loss_phys)
             
    print('Done!')
# Out:
#    >>> Phase 1: Data Fitting ...
# It: 0 [PARAMS:OFF|PHYS:OFF], Loss: 4.563e-01, l1: 1.0000, l2: 0.01000, Time: 7.65s
# It: 100 [PARAMS:OFF|PHYS:OFF], Loss: 2.135e-01, l1: 1.0000, l2: 0.01000, Time: 62.69s
# It: 200 [PARAMS:OFF|PHYS:OFF], Loss: 2.505e-03, l1: 1.0000, l2: 0.01000, Time: 62.50s
# It: 300 [PARAMS:OFF|PHYS:OFF], Loss: 1.159e-03, l1: 1.0000, l2: 0.01000, Time: 62.39s
# It: 400 [PARAMS:OFF|PHYS:OFF], Loss: 7.586e-04, l1: 1.0000, l2: 0.01000, Time: 62.57s
# It: 500 [PARAMS:OFF|PHYS:OFF], Loss: 5.029e-04, l1: 1.0000, l2: 0.01000, Time: 63.22s
# It: 600 [PARAMS:OFF|PHYS:OFF], Loss: 3.601e-04, l1: 1.0000, l2: 0.01000, Time: 63.58s
# It: 700 [PARAMS:OFF|PHYS:OFF], Loss: 3.028e-04, l1: 1.0000, l2: 0.01000, Time: 63.66s
# It: 800 [PARAMS:OFF|PHYS:OFF], Loss: 2.102e-04, l1: 1.0000, l2: 0.01000, Time: 64.41s
# It: 900 [PARAMS:OFF|PHYS:OFF], Loss: 1.689e-04, l1: 1.0000, l2: 0.01000, Time: 64.33s
# It: 1000 [PARAMS:OFF|PHYS:OFF], Loss: 1.497e-04, l1: 1.0000, l2: 0.01000, Time: 64.41s
# It: 1100 [PARAMS:OFF|PHYS:OFF], Loss: 1.218e-04, l1: 1.0000, l2: 0.01000, Time: 64.17s
# It: 1200 [PARAMS:OFF|PHYS:OFF], Loss: 1.714e-04, l1: 1.0000, l2: 0.01000, Time: 64.42s
# It: 1300 [PARAMS:OFF|PHYS:OFF], Loss: 8.679e-05, l1: 1.0000, l2: 0.01000, Time: 64.24s
# It: 1400 [PARAMS:OFF|PHYS:OFF], Loss: 7.364e-05, l1: 1.0000, l2: 0.01000, Time: 64.35s
# It: 1500 [PARAMS:OFF|PHYS:OFF], Loss: 7.108e-05, l1: 1.0000, l2: 0.01000, Time: 64.27s
# It: 1600 [PARAMS:OFF|PHYS:OFF], Loss: 1.419e-04, l1: 1.0000, l2: 0.01000, Time: 64.06s
# It: 1700 [PARAMS:OFF|PHYS:OFF], Loss: 2.677e-04, l1: 1.0000, l2: 0.01000, Time: 63.74s
# It: 1800 [PARAMS:OFF|PHYS:OFF], Loss: 4.465e-05, l1: 1.0000, l2: 0.01000, Time: 64.06s
# It: 1900 [PARAMS:OFF|PHYS:OFF], Loss: 8.040e-04, l1: 1.0000, l2: 0.01000, Time: 64.03s
# It: 2000 [PARAMS:OFF|PHYS:OFF], Loss: 4.378e-05, l1: 1.0000, l2: 0.01000, Time: 64.09s
# It: 2100 [PARAMS:OFF|PHYS:OFF], Loss: 2.495e-04, l1: 1.0000, l2: 0.01000, Time: 64.26s
# It: 2200 [PARAMS:OFF|PHYS:OFF], Loss: 2.197e-05, l1: 1.0000, l2: 0.01000, Time: 64.05s
# It: 2300 [PARAMS:OFF|PHYS:OFF], Loss: 1.939e-05, l1: 1.0000, l2: 0.01000, Time: 64.29s
# It: 2400 [PARAMS:OFF|PHYS:OFF], Loss: 1.795e-05, l1: 1.0000, l2: 0.01000, Time: 64.19s
# It: 2500 [PARAMS:OFF|PHYS:OFF], Loss: 1.723e-05, l1: 1.0000, l2: 0.01000, Time: 64.24s
# It: 2600 [PARAMS:OFF|PHYS:OFF], Loss: 1.461e-05, l1: 1.0000, l2: 0.01000, Time: 63.94s
# It: 2700 [PARAMS:OFF|PHYS:OFF], Loss: 1.950e-05, l1: 1.0000, l2: 0.01000, Time: 64.29s
# It: 2800 [PARAMS:OFF|PHYS:OFF], Loss: 4.484e-04, l1: 1.0000, l2: 0.01000, Time: 64.25s
# It: 2900 [PARAMS:OFF|PHYS:OFF], Loss: 3.258e-04, l1: 1.0000, l2: 0.01000, Time: 64.29s
# Optimizer successfully reset.
#    >>> Phase 2: Physics Discovery ...
# It: 0 [PARAMS:ON|PHYS:ON], Loss: 2.244e-01, l1: 1.0000, l2: 0.01100, Time: 8.52s
# It: 100 [PARAMS:ON|PHYS:ON], Loss: 1.481e-02, l1: 1.0000, l2: 0.00560, Time: 64.40s
# It: 200 [PARAMS:ON|PHYS:ON], Loss: 2.048e-03, l1: 1.0000, l2: 0.00442, Time: 64.35s
# It: 300 [PARAMS:ON|PHYS:ON], Loss: 6.809e-04, l1: 1.0000, l2: 0.00421, Time: 64.47s
# It: 400 [PARAMS:ON|PHYS:ON], Loss: 4.307e-04, l1: 1.0000, l2: 0.00462, Time: 64.78s
# It: 500 [PARAMS:ON|PHYS:ON], Loss: 3.230e-04, l1: 1.0000, l2: 0.00522, Time: 64.84s
# It: 600 [PARAMS:ON|PHYS:ON], Loss: 2.571e-04, l1: 1.0000, l2: 0.00585, Time: 64.67s
# It: 700 [PARAMS:ON|PHYS:ON], Loss: 1.163e-03, l1: 1.0000, l2: 0.00649, Time: 64.93s
# It: 800 [PARAMS:ON|PHYS:ON], Loss: 1.877e-04, l1: 1.0000, l2: 0.00699, Time: 64.43s
# It: 900 [PARAMS:ON|PHYS:ON], Loss: 2.836e-04, l1: 1.0000, l2: 0.00742, Time: 64.42s
# It: 1000 [PARAMS:ON|PHYS:ON], Loss: 1.290e-04, l1: 1.0000, l2: 0.00780, Time: 64.78s
# It: 1100 [PARAMS:ON|PHYS:ON], Loss: 1.158e-04, l1: 1.0000, l2: 0.00808, Time: 64.42s
# It: 1200 [PARAMS:ON|PHYS:ON], Loss: 1.343e-04, l1: 1.0000, l2: 0.00831, Time: 64.59s
# It: 1300 [PARAMS:ON|PHYS:ON], Loss: 9.443e-05, l1: 1.0000, l2: 0.00850, Time: 64.47s
# It: 1400 [PARAMS:ON|PHYS:ON], Loss: 1.508e-03, l1: 1.0000, l2: 0.00871, Time: 64.55s
# It: 1500 [PARAMS:ON|PHYS:ON], Loss: 4.709e-04, l1: 1.0000, l2: 0.00866, Time: 64.41s
# It: 1600 [PARAMS:ON|PHYS:ON], Loss: 7.289e-05, l1: 1.0000, l2: 0.00881, Time: 66.20s
# It: 1700 [PARAMS:ON|PHYS:ON], Loss: 6.901e-05, l1: 1.0000, l2: 0.00888, Time: 65.97s
# It: 1800 [PARAMS:ON|PHYS:ON], Loss: 3.290e-04, l1: 1.0000, l2: 0.00893, Time: 66.07s
# It: 1900 [PARAMS:ON|PHYS:ON], Loss: 7.904e-04, l1: 1.0000, l2: 0.00904, Time: 66.06s
# It: 2000 [PARAMS:ON|PHYS:ON], Loss: 6.135e-05, l1: 1.0000, l2: 0.00903, Time: 66.27s
# It: 2100 [PARAMS:ON|PHYS:ON], Loss: 6.562e-05, l1: 1.0000, l2: 0.00908, Time: 66.20s
# It: 2200 [PARAMS:ON|PHYS:ON], Loss: 5.371e-05, l1: 1.0000, l2: 0.00911, Time: 66.10s
# It: 2300 [PARAMS:ON|PHYS:ON], Loss: 1.115e-04, l1: 1.0000, l2: 0.00916, Time: 66.13s
# It: 2400 [PARAMS:ON|PHYS:ON], Loss: 5.042e-05, l1: 1.0000, l2: 0.00916, Time: 65.87s
# It: 2500 [PARAMS:ON|PHYS:ON], Loss: 6.127e-05, l1: 1.0000, l2: 0.00918, Time: 66.21s
# It: 2600 [PARAMS:ON|PHYS:ON], Loss: 5.928e-04, l1: 1.0000, l2: 0.00921, Time: 65.76s
# It: 2700 [PARAMS:ON|PHYS:ON], Loss: 8.364e-04, l1: 1.0000, l2: 0.00931, Time: 66.74s
# It: 2800 [PARAMS:ON|PHYS:ON], Loss: 3.840e-04, l1: 1.0000, l2: 0.00920, Time: 66.07s
# It: 2900 [PARAMS:ON|PHYS:ON], Loss: 1.451e-04, l1: 1.0000, l2: 0.00929, Time: 66.06s
# It: 3000 [PARAMS:ON|PHYS:ON], Loss: 5.116e-05, l1: 1.0000, l2: 0.00931, Time: 66.18s
# It: 3100 [PARAMS:ON|PHYS:ON], Loss: 4.191e-05, l1: 1.0000, l2: 0.00932, Time: 66.22s
# It: 3200 [PARAMS:ON|PHYS:ON], Loss: 5.774e-05, l1: 1.0000, l2: 0.00936, Time: 66.22s
# It: 3300 [PARAMS:ON|PHYS:ON], Loss: 3.178e-04, l1: 1.0000, l2: 0.00930, Time: 66.00s
# It: 3400 [PARAMS:ON|PHYS:ON], Loss: 2.002e-04, l1: 1.0000, l2: 0.00933, Time: 66.32s
# It: 3500 [PARAMS:ON|PHYS:ON], Loss: 3.128e-05, l1: 1.0000, l2: 0.00939, Time: 66.32s
# It: 3600 [PARAMS:ON|PHYS:ON], Loss: 3.403e-05, l1: 1.0000, l2: 0.00939, Time: 66.26s
# It: 3700 [PARAMS:ON|PHYS:ON], Loss: 4.482e-04, l1: 1.0000, l2: 0.00939, Time: 66.72s
# It: 3800 [PARAMS:ON|PHYS:ON], Loss: 3.588e-05, l1: 1.0000, l2: 0.00938, Time: 66.61s
# It: 3900 [PARAMS:ON|PHYS:ON], Loss: 5.667e-05, l1: 1.0000, l2: 0.00942, Time: 67.06s
# It: 4000 [PARAMS:ON|PHYS:ON], Loss: 2.653e-04, l1: 1.0000, l2: 0.00940, Time: 66.87s
# It: 4100 [PARAMS:ON|PHYS:ON], Loss: 2.905e-05, l1: 1.0000, l2: 0.00947, Time: 66.24s
# It: 4200 [PARAMS:ON|PHYS:ON], Loss: 4.886e-05, l1: 1.0000, l2: 0.00942, Time: 66.59s
# It: 4300 [PARAMS:ON|PHYS:ON], Loss: 3.883e-05, l1: 1.0000, l2: 0.00948, Time: 66.46s
# It: 4400 [PARAMS:ON|PHYS:ON], Loss: 2.752e-05, l1: 1.0000, l2: 0.00944, Time: 66.29s
# It: 4500 [PARAMS:ON|PHYS:ON], Loss: 2.634e-05, l1: 1.0000, l2: 0.00948, Time: 66.11s
# It: 4600 [PARAMS:ON|PHYS:ON], Loss: 2.886e-05, l1: 1.0000, l2: 0.00950, Time: 66.15s
# It: 4700 [PARAMS:ON|PHYS:ON], Loss: 1.505e-04, l1: 1.0000, l2: 0.00945, Time: 66.76s
# It: 4800 [PARAMS:ON|PHYS:ON], Loss: 3.179e-05, l1: 1.0000, l2: 0.00950, Time: 66.05s
# It: 4900 [PARAMS:ON|PHYS:ON], Loss: 1.249e-04, l1: 1.0000, l2: 0.00954, Time: 66.00s
# It: 5000 [PARAMS:ON|PHYS:ON], Loss: 2.968e-05, l1: 1.0000, l2: 0.00951, Time: 66.14s
# It: 5100 [PARAMS:ON|PHYS:ON], Loss: 1.017e-04, l1: 1.0000, l2: 0.00949, Time: 65.77s
# It: 5200 [PARAMS:ON|PHYS:ON], Loss: 6.301e-05, l1: 1.0000, l2: 0.00949, Time: 66.06s
# It: 5300 [PARAMS:ON|PHYS:ON], Loss: 3.504e-05, l1: 1.0000, l2: 0.00953, Time: 66.14s
# It: 5400 [PARAMS:ON|PHYS:ON], Loss: 4.755e-05, l1: 1.0000, l2: 0.00953, Time: 65.83s
# It: 5500 [PARAMS:ON|PHYS:ON], Loss: 7.449e-05, l1: 1.0000, l2: 0.00955, Time: 65.96s
# It: 5600 [PARAMS:ON|PHYS:ON], Loss: 7.967e-05, l1: 1.0000, l2: 0.00949, Time: 66.14s
# It: 5700 [PARAMS:ON|PHYS:ON], Loss: 1.978e-05, l1: 1.0000, l2: 0.00952, Time: 66.05s
# It: 5800 [PARAMS:ON|PHYS:ON], Loss: 2.216e-05, l1: 1.0000, l2: 0.00957, Time: 66.63s
# It: 5900 [PARAMS:ON|PHYS:ON], Loss: 2.458e-05, l1: 1.0000, l2: 0.00956, Time: 66.34s
# It: 6000 [PARAMS:ON|PHYS:ON], Loss: 4.267e-05, l1: 1.0000, l2: 0.00954, Time: 66.24s
# It: 6100 [PARAMS:ON|PHYS:ON], Loss: 5.644e-05, l1: 1.0000, l2: 0.00956, Time: 66.17s
# It: 6200 [PARAMS:ON|PHYS:ON], Loss: 2.555e-05, l1: 1.0000, l2: 0.00958, Time: 66.40s
# It: 6300 [PARAMS:ON|PHYS:ON], Loss: 2.044e-05, l1: 1.0000, l2: 0.00960, Time: 65.99s
# It: 6400 [PARAMS:ON|PHYS:ON], Loss: 9.006e-05, l1: 1.0000, l2: 0.00960, Time: 66.03s
# It: 6500 [PARAMS:ON|PHYS:ON], Loss: 2.721e-05, l1: 1.0000, l2: 0.00955, Time: 66.21s
# It: 6600 [PARAMS:ON|PHYS:ON], Loss: 1.868e-05, l1: 1.0000, l2: 0.00960, Time: 65.87s
# It: 6700 [PARAMS:ON|PHYS:ON], Loss: 1.735e-05, l1: 1.0000, l2: 0.00962, Time: 66.11s
# It: 6800 [PARAMS:ON|PHYS:ON], Loss: 2.433e-04, l1: 1.0000, l2: 0.00968, Time: 66.06s
# It: 6900 [PARAMS:ON|PHYS:ON], Loss: 3.964e-05, l1: 1.0000, l2: 0.00959, Time: 65.80s
# It: 7000 [PARAMS:ON|PHYS:ON], Loss: 1.980e-05, l1: 1.0000, l2: 0.00960, Time: 66.24s
# It: 7100 [PARAMS:ON|PHYS:ON], Loss: 5.855e-05, l1: 1.0000, l2: 0.00961, Time: 66.12s
# It: 7200 [PARAMS:ON|PHYS:ON], Loss: 1.634e-04, l1: 1.0000, l2: 0.00956, Time: 66.23s
# It: 7300 [PARAMS:ON|PHYS:ON], Loss: 4.259e-05, l1: 1.0000, l2: 0.00960, Time: 66.00s
# It: 7400 [PARAMS:ON|PHYS:ON], Loss: 1.665e-05, l1: 1.0000, l2: 0.00962, Time: 66.11s
# It: 7500 [PARAMS:ON|PHYS:ON], Loss: 2.618e-05, l1: 1.0000, l2: 0.00961, Time: 66.10s
# It: 7600 [PARAMS:ON|PHYS:ON], Loss: 3.170e-05, l1: 1.0000, l2: 0.00955, Time: 65.97s
# It: 7700 [PARAMS:ON|PHYS:ON], Loss: 1.853e-04, l1: 1.0000, l2: 0.00962, Time: 65.93s
# It: 7800 [PARAMS:ON|PHYS:ON], Loss: 2.753e-04, l1: 1.0000, l2: 0.00961, Time: 66.05s
# It: 7900 [PARAMS:ON|PHYS:ON], Loss: 2.315e-05, l1: 1.0000, l2: 0.00963, Time: 66.08s
# It: 8000 [PARAMS:ON|PHYS:ON], Loss: 6.874e-05, l1: 1.0000, l2: 0.00969, Time: 66.06s
# It: 8100 [PARAMS:ON|PHYS:ON], Loss: 1.889e-05, l1: 1.0000, l2: 0.00964, Time: 65.96s
# It: 8200 [PARAMS:ON|PHYS:ON], Loss: 2.925e-05, l1: 1.0000, l2: 0.00964, Time: 66.06s
# It: 8300 [PARAMS:ON|PHYS:ON], Loss: 6.538e-05, l1: 1.0000, l2: 0.00964, Time: 65.94s
# It: 8400 [PARAMS:ON|PHYS:ON], Loss: 9.484e-05, l1: 1.0000, l2: 0.00967, Time: 66.15s
# It: 8500 [PARAMS:ON|PHYS:ON], Loss: 1.105e-04, l1: 1.0000, l2: 0.00960, Time: 66.23s
# It: 8600 [PARAMS:ON|PHYS:ON], Loss: 5.329e-05, l1: 1.0000, l2: 0.00963, Time: 66.06s
# It: 8700 [PARAMS:ON|PHYS:ON], Loss: 5.832e-05, l1: 1.0000, l2: 0.00967, Time: 66.45s
# It: 8800 [PARAMS:ON|PHYS:ON], Loss: 5.281e-05, l1: 1.0000, l2: 0.00963, Time: 65.96s
# It: 8900 [PARAMS:ON|PHYS:ON], Loss: 1.445e-05, l1: 1.0000, l2: 0.00965, Time: 66.27s
# It: 9000 [PARAMS:ON|PHYS:ON], Loss: 1.629e-05, l1: 1.0000, l2: 0.00968, Time: 66.66s
# It: 9100 [PARAMS:ON|PHYS:ON], Loss: 1.374e-05, l1: 1.0000, l2: 0.00965, Time: 66.24s
# It: 9200 [PARAMS:ON|PHYS:ON], Loss: 3.723e-04, l1: 1.0000, l2: 0.00966, Time: 66.00s
# It: 9300 [PARAMS:ON|PHYS:ON], Loss: 4.785e-05, l1: 1.0000, l2: 0.00966, Time: 66.11s
# It: 9400 [PARAMS:ON|PHYS:ON], Loss: 7.875e-05, l1: 1.0000, l2: 0.00971, Time: 66.03s
# It: 9500 [PARAMS:ON|PHYS:ON], Loss: 3.596e-05, l1: 1.0000, l2: 0.00962, Time: 66.73s
# It: 9600 [PARAMS:ON|PHYS:ON], Loss: 1.470e-04, l1: 1.0000, l2: 0.00964, Time: 66.12s
# It: 9700 [PARAMS:ON|PHYS:ON], Loss: 9.174e-05, l1: 1.0000, l2: 0.00972, Time: 65.92s
# It: 9800 [PARAMS:ON|PHYS:ON], Loss: 2.416e-05, l1: 1.0000, l2: 0.00967, Time: 67.34s
# It: 9900 [PARAMS:ON|PHYS:ON], Loss: 4.820e-05, l1: 1.0000, l2: 0.00965, Time: 66.08s
# Done!

# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator  
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata
import os

# %%
# Visual setup
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["STIXGeneral"],
    "mathtext.fontset": "stix",
    "font.size": 16
})

def plot_3d_surface(X, Y, Z, z_label, x_train, y_train, fig_size=(9, 8),plot_title=None):
    """Función modular para graficar superficies 3D."""
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    
    surf = ax.plot_surface(X, Y, Z, cmap='coolwarm', alpha=0.9, edgecolor='none')

    if plot_title:
        ax.set_title(plot_title, fontsize=20, pad=15)
    
    # Axis configuration
    z_min = np.min(Z) - 0.2
    ax.set_zlim(z_min, np.max(Z))
    ax.scatter(x_train, y_train, np.full_like(x_train, z_min), c='k', marker='.', s=1, alpha=0.2)
    
    # Z-axis tick reduction to prevent saturation
    ax.zaxis.set_major_locator(MaxNLocator(nbins=4)) 
    
    ax.view_init(elev=35, azim=45)
    ax.set_xlabel('$x$', fontsize=18, labelpad=10)
    ax.set_ylabel('$y$', fontsize=18, labelpad=10)
    ax.set_zlabel(z_label, fontsize=18, rotation=0, labelpad=20)
    ax.set_box_aspect((1.5, 1.5, 0.5))
    
    # Color bar
    cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=15, pad=0.1)
    label_text = z_label.replace('$','').split('(')[0] 
    cbar.set_label(f'${label_text}$', rotation=0, labelpad=15, fontsize=16)
    
    return fig

# %%
if __name__ == "__main__": 
    DATA_PATH = '../Data/taylor_green_data.mat' 
    RESULTS_PATH = 'Results/TaylorGreen/taylor_green_results.npz'
    SAVE_DIR = 'Results/TaylorGreen'
    os.makedirs(SAVE_DIR, exist_ok=True)

    # Load data
    data = scipy.io.loadmat(DATA_PATH)
    results = np.load(RESULTS_PATH)
    
    X_star = data['X_star']
    U_star = data['U_star'] # Shape: [N, 2, T]
    P_star = data['p_star'] # Shape: [N, T]
    t_star = data['t'].flatten() 

    snap = int(results['snap'])
    current_time = t_star[snap]

    print(f"--- SNAPSHOT INFO ---")
    print(f"Snapshot index: {snap}")
    print(f"Physical time (t): {current_time:.4f}")

    u_pred = results['u_pred']
    v_pred = results['v_pred']
    p_pred = results['p_pred']

    lambda_1_value = float(results['lambda_1'])
    lambda_2_value = float(results['lambda_2'])

    x_train = results['x_train']
    y_train = results['y_train']

    # Metrics
    p_exact = P_star[:, snap]
    u_exact = U_star[:, 0, snap]
    v_exact = U_star[:, 1, snap]

    error_u = np.linalg.norm(u_exact.flatten() - u_pred.flatten(), 2) / np.linalg.norm(u_exact.flatten(), 2)
    error_v = np.linalg.norm(v_exact.flatten() - v_pred.flatten(), 2) / np.linalg.norm(v_exact.flatten(), 2)

    # Pressure centering for relative error calculation
    p_pred_centered = p_pred.flatten() - np.mean(p_pred.flatten())
    p_exact_centered = p_exact.flatten() - np.mean(p_exact.flatten())

    error_p = np.linalg.norm(p_exact_centered - p_pred_centered, 2) / np.linalg.norm(p_exact_centered, 2)

    print(f"\n--- PERFORMANCE METRICS ---")
    print(f"Relative L2 (U): {error_u:.4e}")
    print(f"Relative L2 (V): {error_v:.4e}")
    print(f"Relative L2 (P): {error_p:.4e}")

    # Min and max values
    p_pred_min, p_pred_max = np.min(p_pred), np.max(p_pred)
    p_exact_min, p_exact_max = np.min(p_exact), np.max(p_exact)

    print(f"\n--- PRESSURE RANGES ---")    
    print(f"Predicted Pressure (PINN) | Min: {p_pred_min:.4f}, Max: {p_pred_max:.4f}, Range: {p_pred_max - p_pred_min:.4f}")
    print(f"Exact Pressure            | Min: {p_exact_min:.4f}, Max: {p_exact_max:.4f}, Range: {p_exact_max - p_exact_min:.4f}")

    # Interpolation
    nn = 200
    x_plot = np.linspace(X_star[:,0].min(), X_star[:,0].max(), nn)
    y_plot = np.linspace(X_star[:,1].min(), X_star[:,1].max(), nn)
    X, Y = np.meshgrid(x_plot, y_plot)
    
    UU_star = griddata(X_star, u_pred.flatten(), (X, Y), method='cubic')
    VV_star = griddata(X_star, v_pred.flatten(), (X, Y), method='cubic')
    PP_star = griddata(X_star, p_pred.flatten(), (X, Y), method='cubic')
    P_exact_grid = griddata(X_star, p_exact.flatten(), (X, Y), method='cubic')

    # Plotting velocities (3D)
    fig_u = plot_3d_surface(X, Y, UU_star, '$u(x,y)$', x_train, y_train,plot_title="a) $u(x,y,t)$")
    fig_u.savefig(f'{SAVE_DIR}/TaylorGreen_U.png', dpi=300, bbox_inches='tight')
    
    fig_v = plot_3d_surface(X, Y, VV_star, '$v(x,y)$', x_train, y_train,plot_title="b) $v(x,y,t)$")
    fig_v.savefig(f'{SAVE_DIR}/TaylorGreen_V.png', dpi=300, bbox_inches='tight')  

    # Pressure (2D Plots) 
    fig_pressure = plt.figure(figsize=(14, 6))
    data_list = [P_exact_grid, PP_star]
    title_list = ['a) Exact Pressure', 'b) Predicted Pressure (PINN)']
    
    for i, (data_p, title) in enumerate(zip(data_list, title_list)):
        ax = fig_pressure.add_subplot(1, 2, i+1)
        h = ax.imshow(data_p, interpolation='nearest', cmap='coolwarm', 
                      extent=[X_star[:,0].min(), X_star[:,0].max(), X_star[:,1].min(), X_star[:,1].max()], 
                      origin='lower', aspect='auto')
        ax.set_title(title, fontsize=18, pad=15)
        ax.set_xlabel('$x$', fontsize=18)
        ax.set_ylabel('$y$', fontsize=18, rotation=0, labelpad=15)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.1)
        cbar = fig_pressure.colorbar(h, cax=cax)
        cbar.ax.set_title('$p$', fontsize=18, pad=15)

    plt.tight_layout()
    plt.savefig(f'{SAVE_DIR}/TaylorGreen_P.png', dpi=300, bbox_inches='tight')
    plt.show()

    # Discovery Results
    fig_results = plt.figure(figsize=(8, 3))
    ax_txt = fig_results.add_subplot(1, 1, 1)
    ax_txt.axis('off')

    
    txt = (f"Taylor-Green Vortex ($Re=100$)\n\n"
           f"Exact EDP:\n"
           f"$u_t + (u u_x + v u_y) = -p_x + 0.01000(u_{{xx}} + u_{{yy}})$\n\n"
           f"Predicted EDP (PINN):\n"
           f"$u_t + (u u_x + v u_y) = -p_x + {lambda_2_value:.5f}(u_{{xx}} + u_{{yy}})$")

    ax_txt.text(0.5, 0.5, txt, fontsize=14, family='monospace', ha='center', va='center', 
                bbox=dict(facecolor='whitesmoke', alpha=0.9, edgecolor='silver', boxstyle='round,pad=1'))

    fig_results.savefig(f'{SAVE_DIR}/TaylorGreen_Results.png', dpi=300, bbox_inches='tight')

    plt.show()
    plt.show()
# Out:
# --- SNAPSHOT INFO ---
# Snapshot index: 90
# Physical time (t): 4.5455
#
# --- PERFORMANCE METRICS ---
# Relative L2 (U): 8.1403e-03
# Relative L2 (V): 7.8282e-03
# Relative L2 (P): 1.3572e-02
#
# --- PRESSURE RANGES ---
# Predicted Pressure (PINN) | Min: 1.0149, Max: 1.8654, Range: 0.8505
# Exact Pressure            | Min: -0.4167, Max: 0.4169, Range: 0.8335
